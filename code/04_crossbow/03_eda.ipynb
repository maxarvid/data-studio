# %%
import pandas as pd
import matplotlib.pyplot as plt
import re

# %matplotlib inline
# Out:
# /Users/max/.pyenv/versions/3.6.4/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
df = pd.read_csv('arms_data_clean.csv')
df.head()
# Out:
#                                                 link       location  \
# 0  https://www.govdeals.com/index.cfm?fa=Main.Ite...     Benton, TN
# 1  https://www.govdeals.com/index.cfm?fa=Main.Ite...  Nashville, TN
# 2  https://www.govdeals.com/index.cfm?fa=Main.Ite...  Nashville, TN
# 3  https://www.govdeals.com/index.cfm?fa=Main.Ite...     Benton, TN
# 4  https://www.govdeals.com/index.cfm?fa=Main.Ite...     Benton, TN
#
#                make          model  \
# 0         remington  11-87 premier
# 1         remington            700
# 2         remington            700
# 3  smith and wesson         sd9 ve
# 4               eaa    windicator
#
#                                                 name
# 0  remington 11-87 premier semi-automatic 12 gaug...
# 1                                 remington 700 .270
# 2                          remington model 700, .270
# 3      smith and wesson sd9 ve 9mm semi-auto handgun
# 4  eaa windicator .38 special / .357 magnum revolver

# %%
df.shape
# Out:
# (53, 5)

# %%
df[df.name.str.contains('bow')]
# Out:
#                                                  link       location  \
# 18  https://www.govdeals.com/index.cfm?fa=Main.Ite...  Nashville, TN
# 20  https://www.govdeals.com/index.cfm?fa=Main.Ite...  Nashville, TN
# 24  https://www.govdeals.com/index.cfm?fa=Main.Ite...  Nashville, TN
# 25  https://www.govdeals.com/index.cfm?fa=Main.Ite...  Nashville, TN
# 26  https://www.govdeals.com/index.cfm?fa=Main.Ite...  Nashville, TN
# 27  https://www.govdeals.com/index.cfm?fa=Main.Ite...  Nashville, TN
# 28  https://www.govdeals.com/index.cfm?fa=Main.Ite...  Nashville, TN
# 29  https://www.govdeals.com/index.cfm?fa=Main.Ite...  Nashville, TN
# 30  https://www.govdeals.com/index.cfm?fa=Main.Ite...  Nashville, TN
# 31  https://www.govdeals.com/index.cfm?fa=Main.Ite...  Nashville, TN
# 33  https://www.govdeals.com/index.cfm?fa=Main.Ite...  Nashville, TN
# 34  https://www.govdeals.com/index.cfm?fa=Main.Ite...  Nashville, TN
# 35  https://www.govdeals.com/index.cfm?fa=Main.Ite...  Nashville, TN
# ...

# %%
df[df.location == 'Benton, TN']
# Out:
#                                                  link    location  \
# 0   https://www.govdeals.com/index.cfm?fa=Main.Ite...  Benton, TN
# 3   https://www.govdeals.com/index.cfm?fa=Main.Ite...  Benton, TN
# 4   https://www.govdeals.com/index.cfm?fa=Main.Ite...  Benton, TN
# 5   https://www.govdeals.com/index.cfm?fa=Main.Ite...  Benton, TN
# 8   https://www.govdeals.com/index.cfm?fa=Main.Ite...  Benton, TN
# 11  https://www.govdeals.com/index.cfm?fa=Main.Ite...  Benton, TN
# 12  https://www.govdeals.com/index.cfm?fa=Main.Ite...  Benton, TN
# 13  https://www.govdeals.com/index.cfm?fa=Main.Ite...  Benton, TN
# 14  https://www.govdeals.com/index.cfm?fa=Main.Ite...  Benton, TN
# 15  https://www.govdeals.com/index.cfm?fa=Main.Ite...  Benton, TN
# 16  https://www.govdeals.com/index.cfm?fa=Main.Ite...  Benton, TN
# 19  https://www.govdeals.com/index.cfm?fa=Main.Ite...  Benton, TN
# 21  https://www.govdeals.com/index.cfm?fa=Main.Ite...  Benton, TN
# ...

# %%
df.groupby('location').name.value_counts()
# Out:
# location       name
# Benton, TN     hi-standard double nine w-104 .22lr revolver               2
#                beretta bobcat model 21a -- .22 lr semi-auto handgun       1
#                boito br7 20 gauge double barrel shotgun                   1
#                charter arms pathfinder .22 lr revolver                    1
#                eaa windicator .38 special / .357 magnum revolver          1
#                marlin model 101 bolt action .22 lr rifle                  1
#                mossberg 715t .22lr tactical rifle                         1
#                remington 11-87 premier semi-automatic 12 gauge shotgun    1
#                remington 870 express magnum 12 gauge shotgun              1
#                smith and wesson sd9 ve 9mm semi-auto handgun              1
#                spesco model 151 .410 gauge shotgun                        1
#                sterling .25 caliber stainless semi-auto hangun            1
# ...
